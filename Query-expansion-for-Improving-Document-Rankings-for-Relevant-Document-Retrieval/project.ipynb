# %%
import os
import json
from pprint import pprint
from copy import deepcopy

import numpy as np
import pandas as pd

# %%
pdf_dirs = '../document_parses/pdf_json/'
filenames = os.listdir(pdf_dirs)
print("Number of articles retrieved from our Dataset:", len(filenames))

pmc_dirs = '../document_parses/pmc_json/'
filenames2 = os.listdir(pmc_dirs)
print("Number of articles retrieved from our Dataset:", len(filenames2))
# Out:
# Number of articles retrieved from our Dataset: 292221
# Number of articles retrieved from our Dataset: 225681

# %%
all_files = []

for filename in filenames[0:10000]:
    filename = pdf_dirs + filename
    file = json.load(open(filename, 'rb'))
    all_files.append(file)
    
for filename in filenames2[0:10000]:
    filename = pmc_dirs + filename
    file = json.load(open(filename, 'rb'))
    all_files.append(file)

# %%
file = all_files[0]
print("Dictionary keys:", file.keys())
# Out:
# Dictionary keys: dict_keys(['paper_id', 'metadata', 'abstract', 'body_text', 'bib_entries', 'ref_entries', 'back_matter'])

# %%
pprint(all_files[100]['abstract'])
# Out:
# [{'cite_spans': [],
#   'ref_spans': [],
#   'section': 'Abstract',
#   'text': 'In eukaryotic cells, protein sorting is a highly regulated '
#           'mechanism important for many physiological events. After synthesis '
#           'in the endoplasmic reticulum and trafficking to the Golgi '
#           'apparatus, proteins sort to many different cellular destinations '
#           'including the endolysosomal system and the extracellular space. '
#           'Secreted proteins need to be delivered directly to the cell '
#           'surface. Sorting of secreted proteins from the Golgi apparatus has '
#           'been a topic of interest for over thirty years, yet there is still '
#           'no clear understanding of the machinery that forms the post-Golgi '
#           'carriers. Most evidence points to these post-Golgi carriers being '
#           'tubular pleomorphic structures that bud from the trans-face of the '
#           'Golgi. In this review, we present the background studies and '
#           'highlight the key components of this pathway, we then discuss the '
#           'machinery implicated in the formation of these carriers, their '
#           'translocation across the cytosol, and their fusion at the plasma '
#           'membrane.'},
#  {'cite_spans': [],
#   'ref_spans': [],
#   'section': 'Abstract',
#   'text': 'Abbreviations: ATP, adenosine triphosphate; BFA, Brefeldin A; '
#           'CARTS, CARriers of the TGN to the cell Surface; CI-MPR, '
#           'cation-independent mannose-6 phosphate receptor; CtBP3/BARS, '
#           'C-terminus binding protein 3/BFA adenosine diphosphate-ribosylated '
#           'substrate; ER, endoplasmic reticulum; GlcCer, glucosylceramide; '
#           'PAUF, pancreatic adenocarcinoma up-regulated factor; PM, plasma '
#           'membrane; RUSH, retention using selective hooks; SBP, '
#           'streptavidin-binding peptide; SM, sphingomyelin; SNARE, soluble '
#           'N-ethylmaleimide sensitive fusion protein attachment protein '
#           'receptor;SPCA1, secretory pathway calcium ATPase 1; TGN, '
#           'trans-Golgi Network; TIRF, total internal reflection fluorescence; '
#           'ts, temperature sensitive; VSV, vesicular stomatitis virus J o u r '
#           'n a l P r e -p r o o f J o u r n a l P r e -p r o o f J o u r n a l '
#           'P r e -p r o o f J o u r n a l P r e -p r o o f J o u r n a l P r e '
#           '-p r o o f J o u r n a l P r e -p r o o f'}]

# %%
print("body_text type:", type(file['body_text']))
print("body_text length:", len(file['body_text']))
print("body_text keys:", file['body_text'][0].keys())
# Out:
# body_text type: <class 'list'>
# body_text length: 13
# body_text keys: dict_keys(['text', 'cite_spans', 'ref_spans', 'section'])

# %%
print("body_text content:")
pprint(file['body_text'][:2], depth=3)
# Out:
# body_text content:
# [{'cite_spans': [],
#   'ref_spans': [],
#   'section': 'Editor',
#   'text': 'According to current live statistics at the time of editing this '
#           'letter, Russia has been the third country in the world to be '
#           'affected by COVID-19 with both new cases and death rates rising. It '
#           'remains in a position of advantage due to the later onset of the '
#           'viral spread within the country since the worldwide disease '
#           'outbreak.'},
#  {'cite_spans': [],
#   'ref_spans': [],
#   'section': 'Editor',
#   'text': 'The first step in "fighting" the epidemic was nationwide lock down '
#           'on March 30 th , 2020.'}]

# %%
texts = [(di['section'], di['text']) for di in file['body_text']]
texts_di = {di['section']: "" for di in file['body_text']}
for section, text in texts:
    texts_di[section] += text

pprint(list(texts_di.keys()))
# Out:
# ['Editor']

# %%
body = ""

for section, text in texts_di.items():
    body += section
    body += "\n\n"
    body += text
    body += "\n\n"

print(body[:3000])
# Out:
# Editor
#
# According to current live statistics at the time of editing this letter, Russia has been the third country in the world to be affected by COVID-19 with both new cases and death rates rising. It remains in a position of advantage due to the later onset of the viral spread within the country since the worldwide disease outbreak.The first step in "fighting" the epidemic was nationwide lock down on March 30 th , 2020.Most of the multidisciplinary hospitals have been repurposed as dedicated COVID-19 centres, so the surgeons started working as infectious disease specialists. Such a reallocation of health care capacity results in the effective management of this epidemiological problem 1 . The staff has undergone on-line 36-hour training course to become qualified in coronavirus infection treatment.The surgeons of COVID-19 dedicated hospitals do rarely practice surgery. When ICU patients need mechanical ventilation, percutaneous tracheostomy under endoscopic control is mostly performed, as it decreases the aerosol formation, viral load on staff and complications, associated with an endotracheal tube in comparison with surgical tracheostomy 2 . However, it is still associated with the risk of aerosol formation, so different approaches should be considered for a long-time perspective 3 .The majority of the studies dedicated to colorectal diseases are temporarily paused. The teaching and training are mostly translated via online platforms, which has excluded the opportunity to get clinical experience in surgery 4 .The approach to patient routing has changed significantly. If one is not diagnosed with COVID-19 CT scan and laboratory testing are provided immediately. The patients should be admitted to the surgical department, where treatment is provided only to those COVID-19 negative.The patient isolated for more than 2 weeks and COVID-19 negative as a result of 2 subsequent tests is admitted to the surgical department with an option to readmission to the infectious department and can be treated by surgical staff, which does not work with COVID-19 positive patients.The patient, diagnosed with coronavirus infection and treated at home is admitted to COVID-19 dedicated multidisciplinary hospital, where surgical care is provided. Those treated in infectious diseases hospital or COVID-19 dedicated centre are managed by the surgical team present.Surgery has become highly elective, being mostly available for high-risk patients with emergencies, malignancies, cardiovascular pathologies or infections. Preoperative testing in surgical patients with respiratory symptoms and history of travelling or contacting with COVID-19 positive people and postoperative recovery in the operating unit seem to be highly effective measures 5 . A lot of rearrangements are performed locally regarding personal protective equipment, the organization of scrubbing, donning and doffing, and dedicated changing areas. Moreover, observational departments are organized in surgical hospi

# %%
print(all_files[0]['metadata']['title'])
# Out:
# "Multi-faceted" COVID-19: Russian experience

# %%
authors = all_files[1]['metadata']['authors']
pprint(authors[:3])
# Out:
# [{'affiliation': {'institution': 'Uniformed Services University of the Health '
#                                  'Sciences',
#                   'laboratory': '',
#                   'location': {'country': 'USA',
#                                'region': 'Maryland',
#                                'settlement': 'Bethesda'}},
#   'email': '',
#   'first': 'Alex',
#   'last': 'Ba',
#   'middle': ['Yang'],
#   'suffix': ''},
#  {'affiliation': {},
#   'email': '',
#   'first': '|',
#   'last': 'Robert',
#   'middle': [],
#   'suffix': ''},
#  {'affiliation': {'institution': 'Walter Reed National Military Medical Center',
#                   'laboratory': '',
#                   'location': {'country': 'USA',
#                                'region': 'Maryland',
#                                'settlement': 'Bethesda'}},
#   'email': '',
#   'first': 'J',
#   'last': 'Lewis',
#   'middle': [],
#   'suffix': ''}]

# %%
pprint(all_files[4]['metadata'], depth=4)
# Out:
# {'authors': [{'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Oriol',
#               'last': 'Rodríguez-Leor',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Santiago de Compostela, A Coruña',
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': '',
#               'last': 'Belé N Cid-Á Lvarez',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Hospital de León',
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': 'Armando',
#               'last': 'Pé Rez De Prado',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Xavier',
#               'last': 'Rossello',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Universidad de Córdoba',
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': 'Soledad',
#               'last': 'Ojeda',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Ana',
#               'last': 'Serrador',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {},
#               'email': '',
#               'first': 'Ramó',
#               'last': '',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Hospital Virgen de la Arrixaca',
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': '',
#               'last': 'Ló Pez-Palop',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Javier',
#               'last': 'Martín-Moreiras',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Hospital Universitario '
#                                              'IIS-Fundación Jime´nez Dı´az',
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': 'José',
#               'last': 'Ramó',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Hospital de Galdakao-Usansolo',
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': '',
#               'last': 'Rumoroso',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Universitat de Barcelona, '
#                                              "L'Hospitalet de Llobregat",
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': '',
#               'last': 'Cequier',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Borja',
#               'last': 'Ibá Ñ Ez',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Ignacio',
#               'last': 'Cruz-Gonzá Lez',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Universitat de Barcelona, '
#                                              "L'Hospitalet de Llobregat",
#                               'laboratory': '',
#                               'location': {...}},
#               'email': '',
#               'first': 'Rafael',
#               'last': 'Romaguera',
#               'middle': [],
#               'suffix': ''},
#              {'affiliation': {'institution': 'Instituto de Salud Carlos III',
#                               'laboratory': 'Centro de Investigación '
#                                             'Biome´dica en Red Enfermedades '
#                                             'Cardiovaculares (CIBERCV)',
#                               'location': {...}},
#               'email': '',
#               'first': 'Raú',
#               'last': 'Moreno',
#               'middle': ['L'],
#               'suffix': ''}],
#  'title': 'Impact of COVID-19 on ST-segment elevation myocardial infarction '
#           'care. The Spanish experience'}

# %%
bibs = list(file['bib_entries'].values())
pprint(bibs[:2], depth=4)
# Out:
# [{'authors': [{'first': 'L', 'last': 'Tanaka', 'middle': [], 'suffix': ''},
#               {'first': 'M', 'last': 'Alexandru', 'middle': [], 'suffix': ''},
#               {'first': 'S', 'last': 'Jbyeh', 'middle': [], 'suffix': ''},
#               {'first': 'C', 'last': 'Desbrosses', 'middle': [], 'suffix': ''},
#               {'first': 'Z', 'last': 'Bouzit', 'middle': [], 'suffix': ''},
#               {'first': 'G', 'last': 'Cheisson', 'middle': [], 'suffix': ''}],
#   'issn': '',
#   'other_ids': {},
#   'pages': '253--254',
#   'ref_id': 'b0',
#   'title': 'A hybrid approach to tracheostomy in COVID-19 patients ensuring '
#            'staff safety',
#   'venue': 'Br J Surg',
#   'volume': '102',
#   'year': 2020},
#  {'authors': [{'first': 'S', 'last': 'Khan', 'middle': [], 'suffix': ''},
#               {'first': 'A', 'last': 'Mian', 'middle': [], 'suffix': ''}],
#   'issn': '',
#   'other_ids': {},
#   'pages': '',
#   'ref_id': 'b1',
#   'title': 'Medical education: COVID-19 and surgery',
#   'venue': 'Br J Surg',
#   'volume': '107',
#   'year': 2020}]

# %%
from tqdm.notebook import tqdm
from subprocess import check_output

# %%
def format_name(author):
    middle_name = " ".join(author['middle'])
    
    if author['middle']:
        return " ".join([author['first'], middle_name, author['last']])
    else:
        return " ".join([author['first'], author['last']])


def format_affiliation(affiliation):
    text = []
    location = affiliation.get('location')
    if location:
        text.extend(list(affiliation['location'].values()))
    
    institution = affiliation.get('institution')
    if institution:
        text = [institution] + text
    return ", ".join(text)
def format_authors(authors, with_affiliation=False):
    name_ls = []
    
    for author in authors:
        name = format_name(author)
        if with_affiliation:
            affiliation = format_affiliation(author['affiliation'])
            if affiliation:
                name_ls.append(f"{name} ({affiliation})")
            else:
                name_ls.append(name)
        else:
            name_ls.append(name)
    
    return ", ".join(name_ls)

def format_body(body_text):
    texts = [(di['section'], di['text']) for di in body_text]
    texts_di = {di['section']: "" for di in body_text}
    
    for section, text in texts:
        texts_di[section] += text

    body = ""

    for section, text in texts_di.items():
        body += section
        body += "\n\n"
        body += text
        body += "\n\n"
    
    return body

def format_bib(bibs):
    if type(bibs) == dict:
        bibs = list(bibs.values())
    bibs = deepcopy(bibs)
    formatted = []
    
    for bib in bibs:
        bib['authors'] = format_authors(
            bib['authors'], 
            with_affiliation=False
        )
        formatted_ls = [str(bib[k]) for k in ['title', 'authors', 'venue', 'year']]
        formatted.append(", ".join(formatted_ls))

    return "; ".join(formatted)

# %%
def load_files(dirname):
    filenames = os.listdir(dirname)
    raw_files = []

    for filename in tqdm(filenames):
        filename = dirname + filename
        file = json.load(open(filename, 'rb'))
        raw_files.append(file)
    
    return raw_files

def generate_clean_df(all_files):
    cleaned_files = []
    
    for file in tqdm(all_files):
        features = [
            file['paper_id'],
            file['metadata']['title'],
            format_authors(file['metadata']['authors']),
            format_authors(file['metadata']['authors'], 
                           with_affiliation=True),
            format_body(file['abstract']),
            format_body(file['body_text']),
            format_bib(file['bib_entries']),
            file['metadata']['authors'],
            file['bib_entries']
        ]

        cleaned_files.append(features)

    col_names = ['paper_id', 'title', 'authors',
                 'affiliations', 'abstract', 'text', 
                 'bibliography','raw_authors','raw_bibliography']
    clean_df = pd.DataFrame(cleaned_files, columns=col_names)
    clean_df.head()
    
    return clean_df

# %%
print(format_body(file['body_text'])[:3000])
# Out:
# Editor
#
# According to current live statistics at the time of editing this letter, Russia has been the third country in the world to be affected by COVID-19 with both new cases and death rates rising. It remains in a position of advantage due to the later onset of the viral spread within the country since the worldwide disease outbreak.The first step in "fighting" the epidemic was nationwide lock down on March 30 th , 2020.Most of the multidisciplinary hospitals have been repurposed as dedicated COVID-19 centres, so the surgeons started working as infectious disease specialists. Such a reallocation of health care capacity results in the effective management of this epidemiological problem 1 . The staff has undergone on-line 36-hour training course to become qualified in coronavirus infection treatment.The surgeons of COVID-19 dedicated hospitals do rarely practice surgery. When ICU patients need mechanical ventilation, percutaneous tracheostomy under endoscopic control is mostly performed, as it decreases the aerosol formation, viral load on staff and complications, associated with an endotracheal tube in comparison with surgical tracheostomy 2 . However, it is still associated with the risk of aerosol formation, so different approaches should be considered for a long-time perspective 3 .The majority of the studies dedicated to colorectal diseases are temporarily paused. The teaching and training are mostly translated via online platforms, which has excluded the opportunity to get clinical experience in surgery 4 .The approach to patient routing has changed significantly. If one is not diagnosed with COVID-19 CT scan and laboratory testing are provided immediately. The patients should be admitted to the surgical department, where treatment is provided only to those COVID-19 negative.The patient isolated for more than 2 weeks and COVID-19 negative as a result of 2 subsequent tests is admitted to the surgical department with an option to readmission to the infectious department and can be treated by surgical staff, which does not work with COVID-19 positive patients.The patient, diagnosed with coronavirus infection and treated at home is admitted to COVID-19 dedicated multidisciplinary hospital, where surgical care is provided. Those treated in infectious diseases hospital or COVID-19 dedicated centre are managed by the surgical team present.Surgery has become highly elective, being mostly available for high-risk patients with emergencies, malignancies, cardiovascular pathologies or infections. Preoperative testing in surgical patients with respiratory symptoms and history of travelling or contacting with COVID-19 positive people and postoperative recovery in the operating unit seem to be highly effective measures 5 . A lot of rearrangements are performed locally regarding personal protective equipment, the organization of scrubbing, donning and doffing, and dedicated changing areas. Moreover, observational departments are organized in surgical hospi

# %%
for author in authors:
    print("Name:", format_name(author))
    print("Affiliation:", format_affiliation(author['affiliation']))
    print()
# Out:
# Name: Alex Yang Ba
# Affiliation: Uniformed Services University of the Health Sciences, Bethesda, Maryland, USA
#
# Name: | Robert
# Affiliation:
#
# Name: J Lewis
# Affiliation: Walter Reed National Military Medical Center, Bethesda, Maryland, USA
#
# Name: Nora Watson
# Affiliation: Walter Reed National Military Medical Center, Bethesda, Maryland, USA
#
# Name: Charles A Riley
# Affiliation: Walter Reed National Military Medical Center, Bethesda, Maryland, USA
#
# Name: Anthony M Tolisano
# Affiliation: Walter Reed National Military Medical Center, Bethesda, Maryland, USA

# %%
authors = all_files[1]['metadata']['authors']
pprint(authors[:3])
# Out:
# [{'affiliation': {'institution': 'Uniformed Services University of the Health '
#                                  'Sciences',
#                   'laboratory': '',
#                   'location': {'country': 'USA',
#                                'region': 'Maryland',
#                                'settlement': 'Bethesda'}},
#   'email': '',
#   'first': 'Alex',
#   'last': 'Ba',
#   'middle': ['Yang'],
#   'suffix': ''},
#  {'affiliation': {},
#   'email': '',
#   'first': '|',
#   'last': 'Robert',
#   'middle': [],
#   'suffix': ''},
#  {'affiliation': {'institution': 'Walter Reed National Military Medical Center',
#                   'laboratory': '',
#                   'location': {'country': 'USA',
#                                'region': 'Maryland',
#                                'settlement': 'Bethesda'}},
#   'email': '',
#   'first': 'J',
#   'last': 'Lewis',
#   'middle': [],
#   'suffix': ''}]

# %%
authors = all_files[4]['metadata']['authors']
print("Formatting without affiliation:")
print(format_authors(authors, with_affiliation=False))
print("\nFormatting with affiliation:")
print(format_authors(authors, with_affiliation=True))
# Out:
# Formatting without affiliation:
# Oriol Rodríguez-Leor,  Belé N Cid-Á Lvarez, Armando Pé Rez De Prado, Xavier Rossello, Soledad Ojeda, Ana Serrador, Ramó ,  Ló Pez-Palop, Javier Martín-Moreiras, José Ramó,  Rumoroso,  Cequier, Borja Ibá Ñ Ez, Ignacio Cruz-Gonzá Lez, Rafael Romaguera, Raú L Moreno
#
# Formatting with affiliation:
# Oriol Rodríguez-Leor (Instituto de Salud Carlos III, Madrid, Spain),  Belé N Cid-Á Lvarez (Santiago de Compostela, A Coruña, Spain), Armando Pé Rez De Prado (Hospital de León, León, España), Xavier Rossello (Instituto de Salud Carlos III, Madrid, Spain), Soledad Ojeda (Universidad de Córdoba, Córdoba, Spain), Ana Serrador (Instituto de Salud Carlos III, Madrid, Spain), Ramó ,  Ló Pez-Palop (Hospital Virgen de la Arrixaca, El Palmar, Murcia, Spain), Javier Martín-Moreiras (Instituto de Salud Carlos III, Madrid, Spain), José Ramó (Hospital Universitario IIS-Fundación Jime´nez Dı´az, Madrid, Spain),  Rumoroso (Hospital de Galdakao-Usansolo, Galdakao, Vizcaya, Spain),  Cequier (Universitat de Barcelona, L'Hospitalet de Llobregat, Barcelona, Spain), Borja Ibá Ñ Ez (Instituto de Salud Carlos III, Madrid, Spain), Ignacio Cruz-Gonzá Lez (Instituto de Salud Carlos III, Madrid, Spain), Rafael Romaguera (Universitat de Barcelona, L'Hospitalet de Llobregat, Barcelona, Spain), Raú L Moreno (Instituto de Salud Carlos III, Madrid, Spain)

# %%
format_authors(bibs[1]['authors'], with_affiliation=False)
# Out:
# 'S Khan, A Mian'

# %%
bib_formatted = format_bib(bibs[:5])
print(bib_formatted)
# Out:
# A hybrid approach to tracheostomy in COVID-19 patients ensuring staff safety, L Tanaka, M Alexandru, S Jbyeh, C Desbrosses, Z Bouzit, G Cheisson, Br J Surg, 2020; Medical education: COVID-19 and surgery, S Khan, A Mian, Br J Surg, 2020; Elective surgeries during the COVID-19 outbreak, J Lee, J Y Choi, M S Kim, Br J Surg, 2020; Global guidance for surgical care during the COVID-19 pandemic, Covidsurg Collaborative, Br J Surg, 2020; Colorectal cancer services during the COVID-19 pandemic, A Courtney, A M Howell, N Daulatzai, N Savva, O Warren, S Mills, Br J Surg, 2020

# %%
cleaned_files = []

for file in all_files[0:10000]:
    features = [
        file['paper_id'],
        file['metadata']['title'],
        format_authors(file['metadata']['authors']),
        format_authors(file['metadata']['authors'], 
                       with_affiliation=True),
        format_body(file['abstract']),
        format_body(file['body_text']),
        format_bib(file['bib_entries']),
        file['metadata']['authors'],
        file['bib_entries']
    ]
    
    cleaned_files.append(features)

# %%
col_names = [
    'paper_id', 
    'title', 
    'authors',
    'affiliations', 
    'abstract', 
    'text', 
    'bibliography',
    'raw_authors',
    'raw_bibliography'
]

clean_df = pd.DataFrame(cleaned_files, columns=col_names)
clean_df.head()
# Out:
#                                    paper_id  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977
# 1  0000b6da665726420ab8ac9246d526f2f44d5943
# 2  0000b93c66f991236db92dc16fa6db119b27ca12
# 3  0000fcce604204b1b9d876dc073eb529eb5ce305
# 4  000122a9a774ec76fa35ec0c0f6734e7e8d0c541
#
#                                                title  \
# 0       "Multi-faceted" COVID-19: Russian experience
# 1  The cell phone vibration test: A telemedicine ...
# 2  Infections in Hematopoietic Stem Cell Transpla...
# 3
# 4  Impact of COVID-19 on ST-segment elevation myo...
#
#                                              authors  \
# 0
# 1  Alex Yang Ba, | Robert, J Lewis, Nora Watson, ...
# 2                   Biju George, Sanjay Bhattacharya
# 3  Miguel Montserrat, Barcons Marqués, Blanca Cha...
# 4  Oriol Rodríguez-Leor,  Belé N Cid-Á Lvarez, Ar...
#
#                                         affiliations  \
# 0
# 1  Alex Yang Ba (Uniformed Services University of...
# 2  Biju George (Christian Medical College, Vellor...
# 3  Miguel Montserrat, Barcons Marqués (Servicio d...
# 4  Oriol Rodríguez-Leor (Instituto de Salud Carlo...
#
#                                             abstract  \
# 0
# 1  Abstract\n\nObjective: An at home-test for dif...
# 2
# 3  Abstract\n\nContribución de los autores: Rocío...
# 4  Abstract\n\nIntroduction and objectives: The C...
#
#                                                 text  \
# 0  Editor\n\nAccording to current live statistics...
# 1  | INTRODUCTION\n\nAs a consequence of the glob...
# 2  Introduction\n\nInfections are an important ca...
# 3  Introducción: Las residencias de personas mayo...
# 4  \n\nIntroduction and objectives: The COVID-19 ...
#
#                                         bibliography  \
# 0  A hybrid approach to tracheostomy in COVID-19 ...
# 1  Incidence of sudden sensorineural hearing loss...
# 2  Invasive mold infections in allogeneic bone ma...
# 3  Un perfil de las personas mayores en España, A...
# 4  APPENDIX. WORKING GROUP ON THE INFARCT CODE OF...
#
#                                          raw_authors  \
# 0                                                 []
# 1  [{'first': 'Alex', 'middle': ['Yang'], 'last':...
# 2  [{'first': 'Biju', 'middle': [], 'last': 'Geor...
# 3  [{'first': 'Miguel', 'middle': [], 'last': 'Mo...
# 4  [{'first': 'Oriol', 'middle': [], 'last': 'Rod...
#
#                                     raw_bibliography
# 0  {'BIBREF0': {'ref_id': 'b0', 'title': 'A hybri...
# 1  {'BIBREF0': {'ref_id': 'b0', 'title': 'Inciden...
# 2  {'BIBREF0': {'ref_id': 'b0', 'title': 'Invasiv...
# 3  {'BIBREF0': {'ref_id': 'b0', 'title': 'Un perf...
# 4  {'BIBREF0': {'ref_id': 'b0', 'title': 'APPENDI...

# %%
clean_df.to_csv('first_paper_pdf.csv', index=False)

# %%
print(len(cleaned_files))
# Out:
# 10000

# %%
print("Dictionary keys:", all_files[0].keys())
print("Dictionary keys:", all_files[-1].keys())
# Out:
# Dictionary keys: dict_keys(['paper_id', 'metadata', 'abstract', 'body_text', 'bib_entries', 'ref_entries', 'back_matter'])
# Dictionary keys: dict_keys(['paper_id', 'metadata', 'body_text', 'ref_entries', 'back_matter', 'bib_entries'])

# %%
cleaned_files_pmc = []

for file in all_files[10000:]:
    features = [
        file['paper_id'],
        file['metadata']['title'],
        format_authors(file['metadata']['authors']),
        format_authors(file['metadata']['authors'], 
                       with_affiliation=True),
        format_body(file['body_text']),
        format_bib(file['bib_entries']),
        file['metadata']['authors'],
        file['bib_entries']
    ]
    
    cleaned_files_pmc.append(features)

# %%
col_names = [
    'paper_id', 
    'title', 
    'authors',
    'affiliations', 
    'text', 
    'bibliography',
    'raw_authors',
    'raw_bibliography'
]

clean_df_pmc = pd.DataFrame(cleaned_files_pmc, columns=col_names)
clean_df_pmc.head()
# Out:
#      paper_id                                              title  \
# 0  PMC1054884  Recombination Every Day: Abundant Recombinatio...
# 1  PMC1065028  Why can't I visit? The ethics of visitation re...
# 2  PMC1065064  Prospective evaluation of an internet-linked h...
# 3  PMC1065120  Scanning the horizon: emerging hospital-wide t...
# 4  PMC1065257  Characterization of the frameshift signal of E...
#
#                                              authors  \
# 0  Remy Froissart, Denis Roze, Marilyne Uzest, Li...
# 1                                      Sharon Rogers
# 2  Stephen E Lapinsky, Randy Wax, Randy Showalter...
# 3  Ganesh Suntharalingam, Jonathan Cousins, David...
# 4  Emily Manktelow, Kazuhiro Shigemoto, Ian Brierley
#
#                                         affiliations  \
# 0  Remy Froissart, Denis Roze, Marilyne Uzest, Li...
# 1                                      Sharon Rogers
# 2  Stephen E Lapinsky, Randy Wax, Randy Showalter...
# 3  Ganesh Suntharalingam, Jonathan Cousins, David...
# 4  Emily Manktelow, Kazuhiro Shigemoto, Ian Brierley
#
#                                                 text  \
# 0  Introduction\n\nAs increasing numbers of full-...
# 1  Introduction\n\nThe sudden emergence of severe...
# 2  Introduction\n\nThe rate of expansion of medic...
# 3  Introduction\n\nThis series of articles provid...
# 4  INTRODUCTION\n\nProgrammed −1 ribosomal frames...
#
#                                         bibliography  \
# 0  The evolutionary genomics of pathogen recombin...
# 1  , , Learning Lessons from the Toronto Experien...
# 2  Ventilation with lower tidal volumes as compar...
# 3  Use of the Internet in scanning the horizon fo...
# 4  Expression of the Rous sarcoma virus pol gene ...
#
#                                          raw_authors  \
# 0  [{'first': 'Remy', 'middle': [], 'last': 'Froi...
# 1  [{'first': 'Sharon', 'middle': [], 'last': 'Ro...
# 2  [{'first': 'Stephen', 'middle': ['E'], 'last':...
# 3  [{'first': 'Ganesh', 'middle': [], 'last': 'Su...
# 4  [{'first': 'Emily', 'middle': [], 'last': 'Man...
#
#                                     raw_bibliography
# 0  {'BIBREF0': {'title': 'The evolutionary genomi...
# 1  {'BIBREF0': {'title': '', 'authors': [], 'year...
# 2  {'BIBREF0': {'title': 'Ventilation with lower ...
# 3  {'BIBREF0': {'title': 'Use of the Internet in ...
# 4  {'BIBREF0': {'title': 'Expression of the Rous ...

# %%
clean_df_pmc.to_csv('first_paper_pmc.csv', index=False)

# %%
print(len(cleaned_files_pmc))
# Out:
# 10000

# %%
meta_df = pd.read_csv('../metadata.csv') 
nRow, nCol = meta_df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# C:\Users\Anirudh\AppData\Local\Temp\ipykernel_26172\1444453792.py:1: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_df = pd.read_csv('../metadata.csv')
# There are 822279 rows and 19 columns

# %%
meta_df.head(100000)
# Out:
#        cord_uid                                       sha source_x  \
# 0      ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1      02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2      ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3      2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4      9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# ...         ...                                       ...      ...
# 99995  lb0uq85l                                       NaN  Medline
# 99996  zp92kd89                                       NaN  Medline
# 99997  zdomvm1o                                       NaN  Medline
# 99998  gv9h9cfm                                       NaN  Medline
# 99999  7m0lbnzj                                       NaN  Medline
#
#                                                    title  \
# 0      Clinical features of culture-proven Mycoplasma...
# 1      Nitric oxide: a pro-inflammatory mediator in l...
# 2        Surfactant protein-D and pulmonary host defense
# 3                   Role of endothelin-1 in lung disease
# 4      Gene expression in epithelial cells in respons...
# ...                                                  ...
# 99995  A bioinspired mucoadhesive restores lubricatio...
# 99996  Evaluation of the suitability of 19 pharmacoge...
# 99997  Predictors of disease severity and outcome of ...
# 99998  Hospital Outbreak of the SARS-CoV-2 Delta Vari...
# 99999  In vitro Characterisation of SARS-CoV-2 and Su...
#
#                                   doi     pmcid pubmed_id      license  \
# 0               10.1186/1471-2334-1-6  PMC35282  11472636        no-cc
# 1                        10.1186/rr14  PMC59543  11667967        no-cc
# 2                        10.1186/rr19  PMC59549  11667972        no-cc
# 3                        10.1186/rr44  PMC59574  11686871        no-cc
# 4                        10.1186/rr61  PMC59580  11686888        no-cc
# ...                               ...       ...       ...          ...
# 99995  10.1016/j.colsurfb.2020.110977       NaN  32408255  cc-by-nc-nd
# 99996          10.1515/dmdi-2020-0111       NaN  32609649          unk
# 99997          10.2478/rjim-2020-0034       NaN  33155999  cc-by-nc-nd
# 99998            10.1017/ice.2021.471       NaN  34706787          unk
# 99999              10.1111/tbed.13978       NaN  33400387  cc-by-nc-nd
#
#                                                 abstract publish_time  \
# 0      OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1      Inflammatory diseases of the respiratory tract...   2000-08-15
# 2      Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3      Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4      Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# ...                                                  ...          ...
# 99995  Adsorbed lubricious films composed of biomacro...   2020-04-30
# 99996  Objectives Type 2 Diabetes mellitus is a progr...   2020-06-30
# 99997  INTRODUCTION COVID-19 presents a special chall...   2020-11-05
# 99998  The SARS-CoV-2 Delta variant is highly transmi...   2021-10-28
# 99999  Severe acute respiratory syndrome coronavirus-...   2021-01-05
#
#                                                  authors  \
# 0                    Madani, Tariq A; Al-Ghamdi, Aisha A
# 1      Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                        Crouch, Erika C
# 3      Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4      Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# ...                                                  ...
# 99995  Wan, Hongping; Ren, Ke; Kaper, Hans J; Sharma,...
# 99996  Xhakaza, Lettilia; Abrahams-October, Zainonesa...
# 99997  Hasan, Irtiza; Rashid, Tasnuva; Suliman, Sarah...
# 99998  Susky, Erica K; Hota, Susy; Armstrong, Irene E...
# 99999  Marsh, Glenn A; McAuley, Alexander J; Brown, S...
#
#                                                  journal  mag_id  \
# 0                                         BMC Infect Dis     NaN
# 1                                             Respir Res     NaN
# 2                                             Respir Res     NaN
# 3                                             Respir Res     NaN
# 4                                             Respir Res     NaN
# ...                                                  ...     ...
# 99995            Colloids and surfaces. B, Biointerfaces     NaN
# 99996           Drug metabolism and personalized therapy     NaN
# 99997  Romanian journal of internal medicine = Revue ...     NaN
# 99998        Infection control and hospital epidemiology     NaN
# 99999                Transboundary and emerging diseases     NaN
#
#       who_covidence_id arxiv_id  \
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 99995              NaN      NaN
# 99996              NaN      NaN
# 99997              NaN      NaN
# 99998              NaN      NaN
# 99999              NaN      NaN
#
#                                           pdf_json_files  \
# 0      document_parses/pdf_json/d1aafb70c066a2068b027...
# 1      document_parses/pdf_json/6b0567729c2143a66d737...
# 2      document_parses/pdf_json/06ced00a5fc04215949aa...
# 3      document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4      document_parses/pdf_json/5f48792a5fa08bed9f560...
# ...                                                  ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999                                                NaN
#
#                                    pmc_json_files  \
# 0      document_parses/pmc_json/PMC35282.xml.json
# 1      document_parses/pmc_json/PMC59543.xml.json
# 2      document_parses/pmc_json/PMC59549.xml.json
# 3      document_parses/pmc_json/PMC59574.xml.json
# 4      document_parses/pmc_json/PMC59580.xml.json
# ...                                           ...
# 99995                                         NaN
# 99996                                         NaN
# 99997                                         NaN
# 99998                                         NaN
# 99999                                         NaN
#
#                                                      url        s2_id
# 0      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...          NaN
# 1      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 2      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 3      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# 4      https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...          NaN
# ...                                                  ...          ...
# 99995  https://doi.org/10.1016/j.colsurfb.2020.110977...  218648246.0
# 99996  https://doi.org/10.1515/dmdi-2020-0111; https:...  220303838.0
# 99997  https://doi.org/10.2478/rjim-2020-0034; https:...  226269908.0
# 99998  https://doi.org/10.1017/ice.2021.471; https://...  240072164.0
# 99999  https://doi.org/10.1111/tbed.13978; https://ww...  230655530.0
#
# [100000 rows x 19 columns]

# %%
meta_df.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id'],
#       dtype='object')

# %%
meta_df['sha'].isna().sum()
# Out:
# 548864

# %%
meta_df['sha'].head(5)
# Out:
# 0    d1aafb70c066a2068b02786f8929fd9c900897fb
# 1    6b0567729c2143a66d737eb0a2f63f2dce2e5a7d
# 2    06ced00a5fc04215949aa72528f2eeaae1d58927
# 3    348055649b6b8cf2b9a376498df9bf41f7123605
# 4    5f48792a5fa08bed9f56016f4981ae2ca6031b32
# Name: sha, dtype: object

# %%
meta_df1=meta_df[meta_df['sha'].notnull()]
print(len(meta_df1))
# Out:
# 273415

# %%
final_df = pd.concat([clean_df, clean_df_pmc], ignore_index=True, sort =False)

# %%
print(len(final_df))
# Out:
# 20000

# %%
final_df.columns
# Out:
# Index(['paper_id', 'title', 'authors', 'affiliations', 'abstract', 'text',
#        'bibliography', 'raw_authors', 'raw_bibliography'],
#       dtype='object')

# %%
final_df['paper_id'][:5]
# Out:
# 0    0000028b5cc154f68b8a269f6578f21e31f62977
# 1    0000b6da665726420ab8ac9246d526f2f44d5943
# 2    0000b93c66f991236db92dc16fa6db119b27ca12
# 3    0000fcce604204b1b9d876dc073eb529eb5ce305
# 4    000122a9a774ec76fa35ec0c0f6734e7e8d0c541
# Name: paper_id, dtype: object

# %%
final_df['paper_id'].isna().sum()
# Out:
# 0

# %%
print(len(list(set(meta_df1['sha'])&set(clean_df['paper_id']))))
# Out:
# 8806

# %%
pd_merge_all= pd.merge(meta_df, final_df, how='inner',left_on='sha', right_on='paper_id')
print(len(pd_merge_all))
# Out:
# 8808

# %%
pd_merge_all.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title_x', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract_x', 'publish_time', 'authors_x', 'journal',
#        'mag_id', 'who_covidence_id', 'arxiv_id', 'pdf_json_files',
#        'pmc_json_files', 'url', 's2_id', 'paper_id', 'title_y', 'authors_y',
#        'affiliations', 'abstract_y', 'text', 'bibliography', 'raw_authors',
#        'raw_bibliography'],
#       dtype='object')

# %%
pd_merge_all=pd_merge_all[['cord_uid', 'sha', 'source_x', 'title_x', 'doi', 'pmcid', 'pubmed_id',
       'license', 'abstract_x', 'publish_time', 'authors_x', 'journal',
       'mag_id', 'who_covidence_id', 'arxiv_id', 'pdf_json_files',
       'pmc_json_files', 'url', 's2_id', 'paper_id', 'title_y', 'authors_y',
       'affiliations', 'abstract_y', 'text', 'bibliography', 'raw_authors',
       'raw_bibliography']]

# %%
pd_merge_all=pd_merge_all.dropna(subset=['sha', 'text'])  # drop if any of these two columns have nan

# %%
import re
import nltk
import string

# %%
print(len(pd_merge_all))
pd_merge_all=pd_merge_all[pd_merge_all['title_x']!='nan']
print(len(pd_merge_all))
# Out:
# 8808
# 8808

# %%
print(len(pd_merge_all))
pd_merge_all=pd_merge_all[pd_merge_all['abstract_x']!='nan']
print(len(pd_merge_all))
# Out:
# 8808
# 8808

# %%
pd_merge_all.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 1  wnnsmx60  025339bfce1cb8efa81c5accdabefe04dcdac9d2      PMC
# 2  zowp10ts  03203ab50eb64271a9e825f94a1b1a6c46ea14b3      PMC
# 3  fae3sczm  00acd3fd31ed0cde8df286697caefc5298e54df1      PMC
# 4  eflxldnr  050e73f86cfa4ab3f3fc84b0cb55ac779fb9abc2      PMC
#
#                                              title_x  \
# 0    Surfactant protein-D and pulmonary host defense
# 1  Managing emerging infectious diseases: Is a fe...
# 2  Recombination Every Day: Abundant Recombinatio...
# 3  Distinguishing Molecular Features and Clinical...
# 4  La Crosse virus infectivity, pathogenesis, and...
#
#                             doi       pmcid pubmed_id license  \
# 0                  10.1186/rr19    PMC59549  11667972   no-cc
# 1         10.1186/1743-8462-1-7   PMC544965  15679928   cc-by
# 2  10.1371/journal.pbio.0030089  PMC1054884  15737066   cc-by
# 3  10.1371/journal.pone.0001847  PMC2268738  18382652   cc-by
# 4        10.1186/1743-422x-5-25  PMC2276200  18267012   cc-by
#
#                                           abstract_x publish_time  ... s2_id  \
# 0  Surfactant protein-D (SP-D) participates in th...   2000-08-25  ...   NaN
# 1  In the 1980's and 1990's HIV/AIDS was the emer...   2004-11-19  ...   NaN
# 2  Viral recombination can dramatically impact ev...   2005-03-01  ...   NaN
# 3  BACKGROUND: Human rhinoviruses (HRVs) are the ...   2008-04-02  ...   NaN
# 4  BACKGROUND: La Crosse virus (LACV), family Bun...   2008-02-11  ...   NaN
#
#                                    paper_id  \
# 0  06ced00a5fc04215949aa72528f2eeaae1d58927
# 1  025339bfce1cb8efa81c5accdabefe04dcdac9d2
# 2  03203ab50eb64271a9e825f94a1b1a6c46ea14b3
# 3  00acd3fd31ed0cde8df286697caefc5298e54df1
# 4  050e73f86cfa4ab3f3fc84b0cb55ac779fb9abc2
#
#                                              title_y  \
# 0  Surfactant protein-D and pulmonary host defens...
# 1  Managing emerging infectious diseases: Is a fe...
# 2  Recombination Every Day: Abundant Recombinatio...
# 3  Distinguishing Molecular Features and Clinical...
# 4  Virology Journal La Crosse virus infectivity, ...
#
#                                            authors_y  \
# 0                                     Erika C Crouch
# 1                                    Genevieve Howse
# 2  Remy Froissart, Denis Roze, Marilyne Uzest, Li...
# 3  Peter Mcerlean, Laura A Shackelton, Emily Andr...
# 4  Richard S Bennett, Christina M Cress, Jerrold ...
#
#                                         affiliations  \
# 0  Erika C Crouch (Washington University School o...
# 1  Genevieve Howse (La Trobe University, Vic, Aus...
# 2  Remy Froissart (Institut National de la Recher...
# 3  Peter Mcerlean (Royal Children's Hospital, Bri...
# 4  Richard S Bennett (National Institutes of Heal...
#
#                                           abstract_y  \
# 0  Abstract\n\nSurfactant protein-D (SP-D) partic...
# 1  Abstract\n\nIn the 1980's and 1990's HIV/AIDS ...
# 2  Abstract\n\nViral recombination can dramatical...
# 3  Abstract\n\nBackground: Human rhinoviruses (HR...
# 4  Abstract\n\nBackground: La Crosse virus (LACV)...
#
#                                                 text  \
# 0  Introduction\n\nSurfactant protein-D (SP-D) is...
# 1  \n\nThe management of infectious diseases in a...
# 2  Introduction\n\nAs increasing numbers of full-...
# 3  Introduction\n\nHuman rhinoviruses (HRVs) are ...
# 4  \n\nproteins in overlapping reading frames: th...
#
#                                         bibliography  \
# 0  Collectins and pulmonary host defense, E C Cro...
# 1  Human Rights and the HIV Paradox, Justice Kirb...
# 2  The evolutionary genomics of pathogen recombin...
# 3  Molecular characterization of a variant rhinov...
# 4  Medically important arboviruses of the United ...
#
#                                          raw_authors  \
# 0  [{'first': 'Erika', 'middle': ['C'], 'last': '...
# 1  [{'first': 'Genevieve', 'middle': [], 'last': ...
# 2  [{'first': 'Remy', 'middle': [], 'last': 'Froi...
# 3  [{'first': 'Peter', 'middle': [], 'last': 'Mce...
# 4  [{'first': 'Richard', 'middle': ['S'], 'last':...
#
#                                     raw_bibliography
# 0  {'BIBREF0': {'ref_id': 'b0', 'title': 'Collect...
# 1  {'BIBREF0': {'ref_id': 'b0', 'title': 'Human R...
# 2  {'BIBREF0': {'ref_id': 'b0', 'title': 'The evo...
# 3  {'BIBREF0': {'ref_id': 'b0', 'title': 'Molecul...
# 4  {'BIBREF0': {'ref_id': 'b0', 'title': 'Medical...
#
# [5 rows x 28 columns]

# %%
# data cleaning
def clean_dfonecol(new_df,col):
    print(col)
    new_df=pd_merge_all.replace(np.nan,'',regex = True)
    new_df = new_df[pd.notnull(new_df[col])] 
    # lower case
    new_df[col] = new_df[col].apply(lambda x: x.lower()) 
    #punctuation
    new_df[col] = new_df[col].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))
    return new_df


pd_merge_all=clean_dfonecol(pd_merge_all,'title_x')
print(len(pd_merge_all))
pd_merge_all=clean_dfonecol(pd_merge_all,'abstract_x')
print(len(pd_merge_all))
pd_merge_all=clean_dfonecol(pd_merge_all,'text')    # too much text to process
print(len(pd_merge_all))
# Out:
# title_x
# 8808
# abstract_x
# 8808
# text
# 8808

# %%
pd_merge_all.head()[['title_x','abstract_x','text']] # text is cleaner
# Out:
#                                              title_x  \
# 0     surfactant proteind and pulmonary host defense
# 1  managing emerging infectious diseases is a fed...
# 2  recombination every day abundant recombination...
# 3  distinguishing molecular features and clinical...
# 4  la crosse virus infectivity pathogenesis and i...
#
#                                           abstract_x  \
# 0  surfactant proteind spd participates innate re...
# 1  1980s 1990s hivaids emerging infectious diseas...
# 2  viral recombination dramatically impact evolut...
# 3  background human rhinoviruses hrvs frequently ...
# 4  background la crosse virus lacv family bunyavi...
#
#                                                 text
# 0  introduction surfactant proteind spd member co...
# 1  management infectious diseases increasingly co...
# 2  introduction increasing numbers fulllength vir...
# 3  introduction human rhinoviruses hrvs frequentl...
# 4  proteins overlapping reading frames nucleoprot...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
    
def remv_stopwords(new_df,col):
# remove stopwords
    new_df[col]= new_df[col].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
    new_df[col]= new_df[col].str.findall('\w{2,}').str.join(' ')
    return new_df

pd_merge_all=remv_stopwords(pd_merge_all,'abstract_x')
pd_merge_all=remv_stopwords(pd_merge_all,'text') # takes too much memory, so not runnning it
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anirudh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pd_merge_all.head()[['title_x','abstract_x','text']] # text is cleaner
# Out:
#                                              title_x  \
# 0     surfactant proteind and pulmonary host defense
# 1  managing emerging infectious diseases is a fed...
# 2  recombination every day abundant recombination...
# 3  distinguishing molecular features and clinical...
# 4  la crosse virus infectivity pathogenesis and i...
#
#                                           abstract_x  \
# 0  surfactant proteind spd participates innate re...
# 1  1980s 1990s hivaids emerging infectious diseas...
# 2  viral recombination dramatically impact evolut...
# 3  background human rhinoviruses hrvs frequently ...
# 4  background la crosse virus lacv family bunyavi...
#
#                                                 text
# 0  introduction surfactant proteind spd member co...
# 1  management infectious diseases increasingly co...
# 2  introduction increasing numbers fulllength vir...
# 3  introduction human rhinoviruses hrvs frequentl...
# 4  proteins overlapping reading frames nucleoprot...

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import preprocess_documents, preprocess_string
# tockenize abstract
pd_merge_abstract_tokens = pd_merge_all.abstract_x.fillna('').apply(preprocess_string)  # tokenize each abstract to word
# tockenize the text
pd_merge_text_tokens = pd_merge_all.text.fillna('').apply(preprocess_string)  # tokenize each textto word

# %%
pd_merge_abstract_tokens
# Out:
# 0       [surfact, proteind, spd, particip, innat, resp...
# 1       [hivaid, emerg, infecti, diseas, saw, emerg, s...
# 2       [viral, recombin, dramat, impact, evolut, epid...
# 3       [background, human, rhinovirus, hrv, frequent,...
# 4       [background, cross, viru, lacv, famili, bunyav...
#                               ...
# 8803                                                   []
# 8804    [sarscov, variant, concern, voc, hyv, jyv, har...
# 8805    [pandem, outbreak, covid, decemb, later, flow,...
# 8806                                                   []
# 8807    [light, evolv, covid, pandem, associ, american...
# Name: abstract_x, Length: 8808, dtype: object

# %%
pd_merge_text_tokens
# Out:
# 0       [introduct, surfact, proteind, spd, member, co...
# 1       [manag, infecti, diseas, increasingli, complex...
# 2       [introduct, increas, number, fulllength, viral...
# 3       [introduct, human, rhinovirus, hrv, frequent, ...
# 4       [protein, overlap, read, frame, nucleoprotein,...
#                               ...
# 8803    [discuss, potenti, ivermectin, therapeut, opti...
# 8804    [introduct, bcftool, snp, indel, call, freebay...
# 8805    [wwwnaturecomscientificreport, chicken, immun,...
# 8806    [covid, pandem, direct, indirect, effect, peop...
# 8807    [graduat, medic, student, face, transit, unpre...
# Name: text, Length: 8808, dtype: object

# %%
# only process abstract from meta_df1
print(len(meta_df1))
meta_df1=clean_dfonecol(meta_df1,"abstract_x")
print(len(meta_df1))
# Out:
# 273415
# abstract_x
# 8808

# %%
meta_df1=remv_stopwords(meta_df1,'abstract_x')
print(len(meta_df1))
# Out:
# 8808

# %%
meta_df1.reset_index(inplace=True)

# %%
text1=[]
for i in range(len(meta_df1)):
    text1.append(meta_df1['abstract_x'].loc[i])
text2=[]
for i in range(len(meta_df1)):
    text2.append(meta_df1['abstract_x'].loc[i].split())

# %%
import gensim
from gensim import corpora
from pprint import pprint
# Create dictionary
dictionary = corpora.Dictionary(text2)

# %%
# Get information about the dictionary
print(dictionary)
# Out:
# Dictionary<58563 unique tokens: ['abnormal', 'abnormally', 'accumulation', 'accumulations', 'activities']...>

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
show_wordcloud(text2)

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import preprocess_documents, preprocess_string
# tockenize abstract
meta_df_tokens = meta_df1.abstract_x.fillna('').apply(preprocess_string)

# %%
meta_df_tokens[100]
# Out:
# ['sporad',
#  'amyotroph',
#  'later',
#  'sclerosi',
#  'sal',
#  'common',
#  'form',
#  'al',
#  'molecular',
#  'mechan',
#  'underli',
#  'cellular',
#  'damag',
#  'motor',
#  'neuron',
#  'degener',
#  'remain',
#  'elus',
#  'identifi',
#  'molecular',
#  'signatur',
#  'sal',
#  'perform',
#  'genomewid',
#  'express',
#  'profil',
#  'laser',
#  'captur',
#  'microdissectionenrich',
#  'surviv',
#  'motor',
#  'neuron',
#  'mn',
#  'lumbar',
#  'spinal',
#  'cord',
#  'sal',
#  'patient',
#  'rostral',
#  'onset',
#  'caudal',
#  'progress',
#  'correct',
#  'immunolog',
#  'background',
#  'discov',
#  'highli',
#  'specif',
#  'gene',
#  'express',
#  'signatur',
#  'sal',
#  'associ',
#  'phosphoryl',
#  'tdp',
#  'ptdp',
#  'patholog',
#  'transcriptom',
#  'patholog',
#  'correl',
#  'identifi',
#  'casein',
#  'kinas',
#  'csnke',
#  'mrna',
#  'tightli',
#  'correl',
#  'level',
#  'ptdp',
#  'sal',
#  'patient',
#  'enhanc',
#  'crosslink',
#  'immunoprecipit',
#  'human',
#  'sal',
#  'patient',
#  'healthi',
#  'controlderiv',
#  'frontal',
#  'cortex',
#  'reveal',
#  'tdp',
#  'bind',
#  'directli',
#  'regul',
#  'express',
#  'csnke',
#  'mrna',
#  'addition',
#  'abl',
#  'ptdp',
#  'bind',
#  'rna',
#  'cke',
#  'protein',
#  'product',
#  'csnke',
#  'turn',
#  'interact',
#  'tdp',
#  'promot',
#  'cytoplasm',
#  'accumul',
#  'ptdp',
#  'human',
#  'stemcellderiv',
#  'mn',
#  'patholog',
#  'tdp',
#  'phosphoryl',
#  'reciproc',
#  'regul',
#  'cke',
#  'activ',
#  'tdp',
#  'rna',
#  'bind',
#  'framework',
#  'transcriptom',
#  'patholog',
#  'correl',
#  'identifi',
#  'candid',
#  'gene',
#  'relev',
#  'novel',
#  'mechan',
#  'neurodegener',
#  'electron',
#  'supplementari',
#  'materi',
#  'onlin',
#  'version',
#  'articl',
#  'contain',
#  'supplementari',
#  'materi',
#  'avail',
#  'author',
#  'user']

# %%
from rank_bm25 import BM25Okapi

from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import preprocess_documents, preprocess_string
# tockenize abstract
meta_df_tokens = meta_df1.abstract_x.fillna('').apply(preprocess_string) 

# tockenize abstract
pd_merge_abstract_tokens = pd_merge_all.abstract_x.fillna('').apply(preprocess_string)  # tokenize each abstract to word
# tockenize the text
pd_merge_text_tokens = pd_merge_all.text.fillna('').apply(preprocess_string)  # tokenize each textto word

# %%
meta_df_tokens[:100]
# Out:
# 0     [surfact, proteind, spd, particip, innat, resp...
# 1     [hivaid, emerg, infecti, diseas, saw, emerg, s...
# 2     [viral, recombin, dramat, impact, evolut, epid...
# 3     [background, human, rhinovirus, hrv, frequent,...
# 4     [background, cross, viru, lacv, famili, bunyav...
#                             ...
# 95    [background, influenza, epidemiolog, virolog, ...
# 96    [object, studi, aim, evalu, psychometr, proper...
# 97    [porcin, respiratori, diseas, complex, prdc, c...
# 98    [method, protect, radiationinduc, lung, injuri...
# 99    [spread, epidem, determin, structur, contact, ...
# Name: abstract_x, Length: 100, dtype: object

# %%
nltk.download('omw-1.4')
from nltk.corpus import wordnet
def find_syn_ant(word):
    synonyms = []
    antonyms = []

    for syn in wordnet.synsets(word):
        for l in syn.lemmas():
            synonyms.append(l.name())
            if l.antonyms():
                antonyms.append(l.antonyms()[0].name())
    return set(synonyms)

print(find_syn_ant("smoking"))
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Anirudh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# {'smoking', 'smoke', 'fume'}

# %%
from rank_bm25 import BM25Okapi

# %%
bm25_index = BM25Okapi(meta_df_tokens.tolist())

def search(search_string, num_results=10):  # can change the num_results to top 50 or more
    search_tokens = preprocess_string(search_string)
    scores = bm25_index.get_scores(search_tokens)
    top_indexes = np.argsort(scores)[::-1][:num_results]
    return top_indexes

# %%
# now show the abstract of the top index
# Create a BM25Okapi index from the tokens. Implement a search function that returns the top 10 results from the search. 
# Note that in search we are asking the index to return the dataframe indexes of the tokens most similar to the search string.
meta_df1.loc[search('novel coronavirus treatment')][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 3169  background novel coronavirus sarscov2 outbreak...   2020-08-20
# 2838  novel coronavirus disease covid19 pandemic cau...   2020-05-29
# 5895  severe acute respiratory syndrome coronavirus2...   2020-11-05
# 6239  novel coronavirus disease affecting million pe...   2020-06-28
# 7903  coronavirus disease 2019 covid19 expanding rap...   2020-06-04
# 3408  outbreak pneumonia caused novel coronavirus sa...   2020-08-03
# 8624  newly emerging novel coronavirus appeared rapi...   2020-07-15
# 4776  coronavirus disease 2019 covid19 caused novel ...   2021-06-10
# 7272  well documented early days 2019 novel coronavi...   2020-05-20
# 3082  amidst ongoing coronavirus covid19 pandemic ho...   2020-10-24

# %%
meta_df.loc[search('Smoking')][['abstract', 'publish_time']]
# Out:
#                                                abstract publish_time
# 4877  Astrocytes isolated from the brain of newborn ...         1992
# 3140  Deubiquitinating enzymes (DUBs) are important ...   2018-04-05
# 3109  Identifying effective antivirals for treating ...   2018-03-22
# 7019                                                NaN   2007-04-01
# 6223  Hepatitis C virus (HCV) nonstructural protein ...   2016-06-17
# 8553  BACKGROUND: A review of the literature showed ...   2013-06-27
# 2487  Microbial communities reside in healthy tissue...   2016-11-28
# 586   BACKGROUND: Allogeneic bone marrow transplanta...   2011-07-06
# 7031                                                NaN   2014-08-28
# 8406                                                NaN   2020-02-19

# %%
string1='smoking, pre-existing pulmonary disease'
string2= 'Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities'
string3= 'Neonates and pregnant women'
string4=  'Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences'
string5= 'Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors'
string6=  'Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups'
string7=  'Susceptibility of populations'
string8= 'Public health mitigation measures that could be effective for control'

# %%
meta_df1.loc[search(string1)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 3134  background aims severe acute respiratory syndr...   2021-05-03
# 6223  ongoing covid19 pandemic placed spotlight infe...   2020-11-19
# 4877  smoke inhalation induced acute respiratory dis...   2015-05-14
# 2129  complications pneumomediastinum andor pneumoth...   2020-10-14
# 7800  legionnaires disease primarily pneumonic illne...   2020-09-22
# 4479  objective report four patients coronavirus dis...   2020-07-09
# 4198  background whilst covid 19 diagnostic test hig...   2020-12-19
# 438   pneumonia inflammatory diseases pulmonary syst...   2021-01-29
# 3140  raise concerns effectiveness professor hameds ...   2021-02-09
# 6361  situ pulmonary thrombosis may exist covid19 pn...   2020-10-23

# %%
meta_df1.loc[search(string2)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 5571  vaccines reduce clinical severity infection tr...   2020-12-03
# 722   respiratory viral infections rvis common among...   2018-12-08
# 5452  respiratory viral infections frequent causes m...   2013-12-02
# 6626  viral infections important cause pediatric acu...   2016-11-24
# 5923  several severe respiratory virus infections em...   2012-06-08
# 153   influenza viruses cause annual epidemics occas...   2009-10-07
# 7363  world inundated global pandemic coronavirus di...   2021-06-28
# 4596  viral infections small mammals transient rarel...   2005-03-01
# 6265  four decades cause type influenza virus infect...   2010-02-03
# 7102  rna viruses known replicate low fidelity polym...   2019-09-19

# %%
meta_df1.loc[search(string3)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 7420  rapid systematic review carried evaluate curre...   2020-04-27
# 8067  perinatal consequences sarscov2 infection stil...   2021-04-22
# 8146  objectives evaluation clinical course covid19 ...   2020-11-29
# 2167  background covid19 pregnant women suggested im...   2021-02-25
# 6014  background considerable number systematic revi...   2021-01-12
# 2248  purpose study explore relationship pregnant wo...   2021-10-26
# 1533  background pregnant women coronavirus disease ...   2021-09-03
# 4685  purpose evaluate anxiety depression pregnant w...   2020-10-03
# 4910  objective pregnant women historically excluded...   2020-05-19
# 4612  background antenatal depression become common ...   2021-10-26

# %%
meta_df1.loc[search(string4)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 7012  covid19 disrupted everyday life worldwide firs...   2021-04-12
# 1994  current social distancing measures impede covi...   2020-04-30
# 2052  covid19 pandemic resulted significant social e...   2021-08-10
# 8312  background scarcity data health impacts associ...   2021-07-25
# 6708  global pandemics new phenomenon occurred diffe...   2021-03-15
# 8112  covid19 pandemic burning world national health...   2020-06-10
# 8389  paper studies impact sanitary protocols aimed ...   2020-12-24
# 6955  politics may color interpretations facts thus ...   2021-06-01
# 4864  value theory forms bedrock several economic pa...   2020-08-25
# 5345  risk management plays key role uncertain times...   2021-08-03

# %%
meta_df1.loc[search(string5)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 2716  introduction dynamic tools methods assess ongo...   2020-07-16
# 4463  background purpose many statutes comprising sh...   2020-06-17
# 2662  epidemiological model describes transmission d...   2021-02-09
# 5003  background coronavirus disease 2019 covid19 ca...   2020-07-16
# 7487  background knowledge epidemiological features ...   2020-06-18
# 1860  determinants covid19 clinical severity commonl...   2021-08-31
# 4998  paper relates data wellcome sanger institute u...   2021-06-03
# 6992  background reported world health organization ...   2020-02-28
# 7688  background south korea outbreak middle east re...   2017-06-13
# 6588  background middle east respiratory syndrome co...   2016-06-30

# %%
meta_df1.loc[search(string6)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 7625  objective evaluate factors predicting severe s...   2021-02-12
# 2754  background aimed reveal chronic diseases age g...   2021-04-08
# 5731  background although laboratory tests become in...   2021-02-19
# 8376  aims many studies explored clinical characteri...   2020-12-17
# 5505  introduction severe acute respiratory syndrome...   2021-03-14
# 8564  background 2009 severe fever thrombocytopenia ...   2013-11-13
# 3830  background studied labconfirmed covid19 infect...   2021-08-13
# 7168  background studies patients heart failure hf h...   2021-07-17
# 3285  background aimed investigate clinical characte...   2020-11-18
# 6220  paper aim understanding broad spectrum factors...   2021-06-16

# %%
meta_df1.loc[search(string7)][['abstract_x', 'publish_time']]
# Out:
#                                              abstract_x publish_time
# 2913  genetic analysis pathogen genomes powerful app...   2013-03-19
# 2966  abstract increasingly common infectious diseas...   2005-03-01
# 5434  background carboxypeptidase protein called ace...   2020-12-02
# 7690  deterministic model formulated employed analys...   2021-07-27
# 6478  model calculate fraction infected population n...   2020-09-10
# 3139  research work present mathematical model novel...   2020-07-01
# 7252  global pandemic outbreak coronavirus disease 2...   2021-07-28
# 4653  severe acute respiratory syndrome coronavirus ...   2020-04-17
# 3372  current pandemic brought renewed appreciation ...   2021-06-09
# 4574  covid19 pandemic markedly impacted cultural po...   2021-08-03

# %%
meta_df1.loc[search(string8)][['abstract_x', 'publish_time','title_x']]
# Out:
#                                              abstract_x publish_time  \
# 6117  public health interventions implemented mitiga...   2020-05-26
# 2176  mitigation measures including stayathome order...   2020-11-13
# 1919  novel coronavirus sarscov2 disease causes covi...   2020-04-07
# 3163  midst global pandemic prevention methods stand...   2021-08-04
# 1926  data collection processing via digital public ...   2020-04-21
# 8052  development strategies mitigating severity cov...   2021-03-22
# 8419  beginning 2020 global outbreak novel coronavir...   2021-04-15
# 3241  testimony us congress march 11 2020 members ho...   2020-08-12
# 7196  countries affected covid19 pandemic repeatedly...   2021-03-26
# 7296  introduction widespread availability effective...   2021-04-30
#
#                                                 title_x
# 6117  quantifying the role of social distancing pers...
# 2176  declines in sarscov2 transmission hospitalizat...
# 1919  the impact of public safety measures on the sp...
# 3163  perception versus preference the role of selfa...
# 1926  digital tools against covid19 framing the ethi...
# 8052  sarscov2 transmission and control in a hospita...
# 8419  governance capability of the public health sys...
# 3241  public health lessons learned from biases in c...
# 7196  drastic reductions in mental wellbeing observe...
# 7296  perceived social norms as determinants of adhe...

# %%
meta_df1['title_x'][6117]
# Out:
# 'quantifying the role of social distancing personal protection and case detection in mitigating covid19 outbreak in ontario canada'

# %%
meta_df1.loc[search('quantifying the role of social distancing personal protection and case detection in mitigating covid19 outbreak in ontario canada')][['abstract_x', 'publish_time','title_x']]
# Out:
#                                              abstract_x publish_time  \
# 6117  public health interventions implemented mitiga...   2020-05-26
# 5387  covid19 mitigation commonly involves contact t...   2020-12-02
# 3747  objective describe immediate impact covid 19 p...   2021-05-31
# 5013  cdc recommends number mitigation behaviors pre...   2020-10-30
# 4020  motivation early detection isolation covid19 p...   2021-02-08
# 5495  covid19 pandemic necessitated public health me...   2020-12-31
# 8052  development strategies mitigating severity cov...   2021-03-22
# 1707  abstract background since beginning covid19 pa...   2021-10-07
# 4103  background 2020 us schools closed due sarscov2...   2021-01-29
# 8179  abstract financial incentives fis green buildi...   2021-01-31
#
#                                                 title_x
# 6117  quantifying the role of social distancing pers...
# 5387  smart investment of virus rna testing resource...
# 3747  the impact of the covid‐19 pandemic on the ont...
# 5013  covid19 mitigation behaviors by age group — un...
# 4020  covidhunter an accurate flexible and environme...
# 5495  understanding the impact of the covid19 pandem...
# 8052  sarscov2 transmission and control in a hospita...
# 1707  time trends in social contacts before and duri...
# 4103  the experience of two independent schools with...
# 8179  evaluation of financial incentives for green b...
